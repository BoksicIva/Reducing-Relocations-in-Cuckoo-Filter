# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
output_header = ["k","rows","columns","mnk","reduced","k-mers_inserted","num_k_mers","insertion_percentage","average_insertion_time","load_factor","num_reloc"]

output_df = pd.read_csv("../Resource_files/output.csv")
output_df.columns = output_header
output_df
# Out:
#        k    rows  columns  mnk  reduced  k-mers_inserted  num_k_mers  \
# 0     10      50      100  100        0             5000     5594758
# 1     10     500      100  100        1            50000     5594758
# 2     10     500      100  100        0            50000     5594758
# 3     10    5000      100  100        1           500000     5594758
# 4     10    5000      100  100        0           500000     5594758
# ..   ...     ...      ...  ...      ...              ...         ...
# 64  1000    5000      100  100        0           500000     5593768
# 65  1000   50000      100  100        1          5000000     5593768
# 66  1000   50000      100  100        0          4998657     5593768
# 67  1000  500000      100  100        1          5548243     5593768
# 68  1000  500000      100  100        0          5548243     5593768
#
#     insertion_percentage  average_insertion_time  load_factor  num_reloc
# ...

# %%
sns.relplot(x="load_factor", y="average_insertion_time", hue="reduced", style="reduced",  dashes=True, markers=True, kind="line", data=output_df,height=5,aspect=5);
plt.savefig('../Resource_files/Pictures/load_factor avg_time.png')

# %%
sns.relplot(x="load_factor", y="num_reloc", hue="reduced", style="reduced",  dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/load_factor num_reloc.png')

# %%
sns.relplot(x="average_insertion_time", y="num_reloc", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/avg_time num_reloc.png')

# %%
sns.relplot(x="insertion_percentage", y="num_k_mers", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/insertion_percentage num_k_mers.png')

# %%
sns.relplot(x="load_factor", y="k-mers_inserted", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/load_factor k-mers_inserted.png')

# %%
sns.relplot(x="load_factor", y="insertion_percentage", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/load_factor insertion_percentage.png')

# %%
sns.relplot(x="load_factor", y="k", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/load_factor k.png')

# %%
sns.relplot(x="num_reloc", y="k", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/k num_reloc.png')

# %%
sns.relplot(x="k", y="average_insertion_time", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/avg_time k.png')

# %%
sns.relplot(x="insertion_percentage", y="k", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/insertion_percentage k.png')

# %%
sns.relplot(x="average_insertion_time", y="insertion_percentage", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/insertion_percentage average_insertion_time.png')

# %%
sns.relplot(x="num_reloc", y="k-mers_inserted", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/num_reloc k_mers_inserted.png')

# %%
sns.relplot(x="k-mers_inserted", y="k", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/k k_mers_inserted.png')

# %%
sns.relplot(x="average_insertion_time", y="k-mers_inserted", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/avg_time k_mers_inserted.png')

# %%
sns.relplot(x="insertion_percentage", y="num_reloc", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=output_df,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/num_reloc insertion_percentage.png')

# %%
group=output_df.groupby(["rows","columns"])
group.head()
# Out:
#      k    rows  columns  mnk  reduced  k-mers_inserted  num_k_mers  \
# 0   10      50      100  100        0             5000     5594758
# 1   10     500      100  100        1            50000     5594758
# 2   10     500      100  100        0            50000     5594758
# 3   10    5000      100  100        1           500000     5594758
# 4   10    5000      100  100        0           500000     5594758
# 5   10   50000      100  100        1           930838     5594758
# 6   10   50000      100  100        0           930838     5594758
# 7   10  500000      100  100        1           930838     5594758
# 8   10  500000      100  100        0           930838     5594758
# 9   20      50      100  100        1             5000     5594748
# 10  20      50      100  100        0             5000     5594748
# 11  20     500      100  100        1            50000     5594748
# 12  20     500      100  100        0            50000     5594748
# ...

# %% [markdown]
# ###  Podatkovni skup iz output_search.csv

# %%
output_search_header = ["k_","num_found","num_of_random_k_mers","found_percentage"]

output_search_df = pd.read_csv("../Resource_files/output_search.csv")
output_search_df.columns=output_search_header
output_search_df
# Out:
#       k_  num_found  num_of_random_k_mers  found_percentage
# 0     10     812129               5000000           16.2426
# 1     10    5000000               5000000          100.0000
# 2     10    5000000               5000000          100.0000
# 3     10    5000000               5000000          100.0000
# 4     10    5000000               5000000          100.0000
# ..   ...        ...                   ...               ...
# 64  1000    5000000               5000000          100.0000
# 65  1000    5000000               5000000          100.0000
# 66  1000    5000000               5000000          100.0000
# 67  1000    5000000               5000000          100.0000
# 68  1000    5000000               5000000          100.0000
#
# [69 rows x 4 columns]

# %%
data=pd.concat([output_df, output_search_df], axis=1)
data
# Out:
#        k    rows  columns  mnk  reduced  k-mers_inserted  num_k_mers  \
# 0     10      50      100  100        0             5000     5594758
# 1     10     500      100  100        1            50000     5594758
# 2     10     500      100  100        0            50000     5594758
# 3     10    5000      100  100        1           500000     5594758
# 4     10    5000      100  100        0           500000     5594758
# ..   ...     ...      ...  ...      ...              ...         ...
# 64  1000    5000      100  100        0           500000     5593768
# 65  1000   50000      100  100        1          5000000     5593768
# 66  1000   50000      100  100        0          4998657     5593768
# 67  1000  500000      100  100        1          5548243     5593768
# 68  1000  500000      100  100        0          5548243     5593768
#
#     insertion_percentage  average_insertion_time  load_factor  num_reloc  \
# ...

# %%
sns.relplot(x="found_percentage", y="load_factor", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=data,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/found_percentage load_factor.png')

# %%
sns.relplot(x="num_reloc", y="found_percentage", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=data,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/found_percentage num_reloc.png')

# %%
sns.relplot(x="average_insertion_time", y="found_percentage", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=data,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/found_percentage average_insertion_time .png')

# %%
sns.relplot(x="found_percentage", y="insertion_percentage", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=data,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/found_percentage insertion_percentage .png')

# %%
sns.relplot(x="found_percentage", y="k-mers_inserted", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=data,height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/found_percentage k-mers_inserted .png')

# %%
sns.relplot(x="found_percentage", y="k", hue="reduced", style="reduced", dashes=True, markers=True, kind="line", data=data, height=10,aspect=1.6);
plt.savefig('../Resource_files/Pictures/found_percentage k .png')
